# %% [markdown]
# <h1 style='text-align:center'> Module 1 Assessment</h1>

# %% [markdown]
# Congrats on completing Mod 1! In this assessment we'll cover Python fundamentals, working with statistical data, pandas and numpy, data visualization and linear regression.

# %% [markdown]
# ## Python Fundamentals

# %% [markdown]
# In the first section, we will work with various Python data types and try to accomplish certain tasks using some Python fundamentals. Below, we've defined a dictionary with soccer player names as keys for nested dictionaries containing information about each players age, nationality, and a list of teams they have played for.

# %%
players = {
	'L. Messi': {
		'age': 31,
		'nationality': 'Argentina',
		'teams': ['Barcelona']
	},
	'Cristiano Ronaldo': {
		'age': 33,
		'nationality': 'Portugal',
		'teams': ['Juventus', 'Real Madrid', 'Manchester United']
	},
	'Neymar Jr': {
		'age': 26,
		'nationality': 'Brazil',
		'teams': ['Santos', 'Barcelona', 'Paris Saint-German']
	},
	'De Gea': {
		'age': 27,
		'nationality': 'Spain',
		'teams': ['Atletico Madrid', 'Manchester United']
	},
	'K. De Bruyne': {
		'age': 27,
		'nationality': 'Belgium',
		'teams': ['Chelsea', 'Manchester City']
	}
}

# %% [markdown]
# <b>1) Create a function that takes in a dictionary and returns a list of keys for that dictionary. In our case it should return a list of player names. Use python's documentation on dictionaries for help if needed. We started the function below for you, complete it below the doc string (don't forget your return statement!)</b>

# %%
def get_keys(dict_):
    '''
    Generate list of keys in dictionary
    
    Parameters
    ----------
    dict_ : dictionary object
        Dictionary with player names as keys
    Returns
    --------
    keys_ :  list object
        List object containing keys for the dictionary
    '''
    return(players.keys())

# %%
#assign output of get_keys function to player_names
player_names = get_keys(players)
player_names
# Out:
# dict_keys(['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', 'De Gea', 'K. De Bruyne'])

# %% [markdown]
# <b> 2) Great! Now that we have each players name, let's use that information to create a list of tuples containing each player's name along with their nationality.</b>

# %%
def get_nationality(dict_, player_names):
    '''
    Generate list of tuples such that the first element in the tuple is 
    a players name and the second is their nationality 
    [('L. Messi', 'Argentina'), ('Christiano Ronaldo', 'Portugal'), ...]
    
    Parameters
    ----------
    dict_ : dictionary object
        Dictionary of player information
    player_names: 
        List of player names
    Returns
    --------
    nationalities :  list object
        List object containing tuples of players name and their nationality 
    '''
    #player_names, players>nationality
    nationality = []
    for i in player_names:
        nationality.append([i, dict_[i]['nationality']])
    return nationality

# %%
print(players["L. Messi"]["nationality"])
# Out:
# Argentina

# %%
print(player_names)
# Out:
# dict_keys(['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', 'De Gea', 'K. De Bruyne'])

# %%
nationality = get_nationality(players, player_names)
print(nationality)
# Out:
# [['L. Messi', 'Argentina'], ['Cristiano Ronaldo', 'Portugal'], ['Neymar Jr', 'Brazil'], ['De Gea', 'Spain'], ['K. De Bruyne', 'Belgium']]

# %% [markdown]
# #### 3) Now, create a function that obtains players based on which teams they've been on.

# %%
def get_players_on_team(dict_,team_name):
    '''
    Generate a list of players that have ever played on a given team.
    
    Parameters
    ----------
    dict_ : dictionary object
        Dictionary of player information
    team_name: string
        Name of team to be searched for
    
    Returns
    --------
    player_list : list object
        List containing player names
    '''
    player_list = []
    for i in dict_: 
        for team in dict_[i]['teams']:
            if team == team_name:
                player_list.append([i])
    return player_list

# %%
players_on_manchester_united = get_players_on_team(players,'Manchester United')
print(players_on_manchester_united)
# Out:
# [['Cristiano Ronaldo'], ['De Gea']]

# %% [markdown]
# ## Pandas and Numpy

# %% [markdown]
# In this section you will be doing some preprocessing and exploratory data analysis for a dataset for the videogame FIFA19 (https://www.kaggle.com/karangadiya/fifa19).  The dataset contains both data for the game as well as information about the players' real life careers.  You will be building toward running a regression.

# %% [markdown]
# <b>1) Read the CSV file into a pandas dataframe
#
# The data you'll be working with is found in a file called './data/fifa.csv'  Complete the first function below to read it into a pandas dataframe.
#
# Check the contents of your dataframe with `df.head()`</b>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CAEA-B542
#
#  Directory of C:\Users\kayce_000\Flatiron School\Module 1\Assessment\module-1-code-challenge-round-1-online-ds-pt-051319-dsc-module-1-assessment-1561566719
#
# 07/18/2019  07:10 PM    <DIR>          .
# 07/18/2019  07:10 PM    <DIR>          ..
# 07/02/2019  07:29 PM    <DIR>          .ipynb_checkpoints
# 07/02/2019  07:29 PM             1,849 CONTRIBUTING.md
# 07/02/2019  07:29 PM    <DIR>          data
# 07/18/2019  07:10 PM           213,977 index.ipynb
# 07/02/2019  07:29 PM             1,371 LICENSE.md
# 07/02/2019  07:29 PM            18,263 Preliminary Data Cleaning Notebook.ipynb
# 07/02/2019  07:29 PM            10,072 README.md
#                5 File(s)        245,532 bytes
#                4 Dir(s)  168,875,708,416 bytes free

# %%
# CODE HERE
def get_fifa_data():
    '''
    Parameters
    ----
    
    Returns 
    ----
    df : Pandas DataFrame Object
        dataframe containing data from fifa.csv
    '''

# %%
df = pd.read_csv('./data/fifa.csv')
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0       226500.0
# 1      7.0        11.0       15.0           14.0       11.0       127100.0
# 2      9.0         9.0       15.0           15.0       11.0       228100.0
# 3     90.0        85.0       87.0           88.0       94.0       138600.0
# 4     15.0        13.0        5.0           10.0       13.0       196400.0
#
# [5 rows x 89 columns]

# %% [markdown]
# <b>2) Check for duplicates
#
# First, check how many rows are in the dataset, then check how many unique values are in the "ID" column.</b>

# %%
#code here to see the size of the dataframe
df.shape
# Out:
# (20000, 89)

# %%
#code here to check number of unique ids
df['ID'].value_counts()
# Out:
# 223115    2
# 207629    2
# 225798    2
# 184001    2
# 222916    2
# 183160    2
# 183007    2
# 234371    2
# 208589    2
# 217990    2
# 209317    2
# 224140    2
# 189325    2
# 243554    2
# 227740    2
# 211901    2
# 209852    2
# 179903    2
# 199627    2
# 224108    2
# 223921    2
# 206492    2
# 238354    2
# 215864    2
# 170818    2
# 207619    2
# 191184    2
# 193166    2
# 223979    2
# 214704    2
#          ..
# 213778    1
# 240399    1
# 244493    1
# 242444    1
# 164618    1
# 236297    1
# 240323    1
# 242229    1
# 240383    1
# 205566    1
# 244477    1
# 209660    1
# 199419    1
# 239005    1
# 193268    1
# 213746    1
# 207599    1
# 209644    1
# 232171    1
# 221926    1
# 193252    1
# 245150    1
# 54037     1
# 240351    1
# 176860    1
# 199387    1
# 223959    1
# 228053    1
# 240335    1
# 198657    1
# Name: ID, Length: 18207, dtype: int64

# %% [markdown]
# <b> 3) Drop Duplicates
#
# It looks like there are duplicates.  Get rid of them by dropping duplicate rows. After you have dropped them, see how many rows are remaining.</b>

# %%
df.duplicated(subset = "ID").sum()
# Out:
# 1793

# %%
df.drop_duplicates(subset = "ID", inplace = True)

# %%
#now see how many rows there are
df.shape
# Out:
# (18207, 89)

# %% [markdown]
# <b> 4. Drop n/a rows for "Release Clause"
#
# Drop rows for which "Release Clause" is none or not given. This is part of a soccer player's contract dealing with being bought out by another team. Release Clause will be the target variable for our regression model.  After you have dropped them, see how many rows are remaining.</b>

# %%
df['Release Clause'].isnull().any()
# Out:
# True

# %%
#code here to drop n/a rows
df['Release Clause'].dropna(inplace = True)

# %%
df["Release Clause"].isnull().any()
# Out:
# False

# %%
#now check how many rows are left 
df["Release Clause"].value_counts().sum()
# Out:
# 16643

# %% [markdown]
# <b> 5) Convert players' heights to inches. Replace the original height column.
# First create a function, then use it on your dataframe. Create a function that convert a string into a integer and then apply that function to all of the height column.</b>

# %%
#code here to write a helper function
def convert_height(height):
    '''
    inputs: height (string)
    ----
    returns: height in inches (int)
    '''
    
    return (int(height.split("'")[0])*12)+(int(height.split("'")[1]))
    #seperate based on apostrophe 
    #convert to int
    #perform (feet*12)+inches
    #don't forget to return

# %%
int(df.loc[0,'Height'].split("'")[0])
# Out:
# 5

# %%
#test here
convert_height("5'7")
# Out:
# 67

# %%
#code here to use the function on the height column
#create a new column- height in inches
#take the height in feet and apply convert_height
df['height_in_inches'] = df['Height'].apply(convert_height)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-f8dfa162d761> in <module>
#       2 #create a new column- height in inches
#       3 #take the height in feet and apply convert_height
# ----> 4 df['height_in_inches'] = df['Height'].apply(convert_height)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-24-85598755e52e> in convert_height(height)
#       7     '''
#       8
# ----> 9     return (int(height.split("'")[0])*12)+(int(height.split("'")[1]))
#      10     #seperate based on apostrophe
#      11     #convert to int
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df["Height"]

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# <b> 1) Make a histogram of players age
#
# _Add a title and x axis label._ Use whichever plotting library you are most comfortable with. </b>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#histogram
sns.distplot(df["Age"]).set_title("Age of Players")
# Out:
# Text(0.5, 1.0, 'Age of Players')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %% [markdown]
# <b> 2) Make a bar chart for the 10 countries with the most players (by nationality)</b>
#
# Make sure to include x labels on your chart!

# %%
#code here to get the top 10 countries with the most players
top_ten = df["Nationality"].value_counts()[:10]
print (top_ten)
#x = country
#y = player counts
country = ["England","Germany","Spain","Argentina","France","Brazil","Italy","Colombia","Japan","Netherlands"]
player_counts = [1662, 1198, 1072, 937, 914, 827, 702, 618, 478, 453]
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
#code here to plot a bar chart
fig = sns.barplot(x = country, y= player_counts).set_title("10 Countries with the Most Players")

# %% [markdown]
# <b> 3) Make a scatter plot for the player stats StandingTackle and SlidingTackle
#
# What can we say about these two features? </b>

# %%
#Code below- watched video for assistance

# %%
#code here to plot a scatterplot
plt.scatter(df["StandingTackle"], df["SlidingTackle"])

# %% [markdown]
# This data is highly correlated.

# %% [markdown]
# ### Exploring Statistical Data

# %% [markdown]
# We'll continue using the same FIFA 2019 dataset.  This section will assess your ability to use numpy and work with summary statistics.

# %% [markdown]
# <b>1) Convert the Release Clause Price from Euros to Dollars
#
# Create a new column that has the 'release_clause' in dollars.
#
# 1.2 Dollars = 1 Euro.</b>

# %%
#code here to convert the column of euros to dollars
df['release_clause_dollars'] = df['Release Clause']*1.2

# %% [markdown]
# <b>2) Get summary statistics for all numeric columns
#
# (Please don't do each column individually!)</b>

# %%
#code here
df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    5403.606964  214298.338606     25.122206     66.238699     71.307299
# std     2703.044843   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     3172.000000  200315.500000     21.000000     62.000000     67.000000
# 50%     5448.000000  221759.000000     25.000000     66.000000     71.000000
# 75%     7723.500000  236529.500000     28.000000     71.000000     75.000000
# max     9999.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# std      272.586016                  0.394031      0.660456      0.756164
# min      731.000000                  1.000000      1.000000      1.000000
# 25%     1457.000000                  1.000000      3.000000      2.000000
# 50%     1635.000000                  1.000000      3.000000      2.000000
# 75%     1787.000000                  1.000000      3.000000      3.000000
# max     2346.000000                  5.000000      5.000000      5.000000
#
#        Jersey Number  ...       Marking  StandingTackle  SlidingTackle  \
# count   18147.000000  ...  18159.000000    18159.000000   18159.000000
# mean       19.546096  ...     47.281623       47.697836      45.661435
# std        15.947765  ...     19.904397       21.664004      21.289135
# min         1.000000  ...      3.000000        2.000000       3.000000
# 25%         8.000000  ...     30.000000       27.000000      24.000000
# 50%        17.000000  ...     53.000000       55.000000      52.000000
# 75%        26.000000  ...     64.000000       66.000000      64.000000
# max        99.000000  ...     94.000000       93.000000      91.000000
#
#            GKDiving    GKHandling     GKKicking  GKPositioning    GKReflexes  \
# count  18159.000000  18159.000000  18159.000000   18159.000000  18159.000000
# mean      16.616223     16.391596     16.232061      16.388898     16.710887
# std       17.695349     16.906900     16.502864      17.034669     17.955119
# min        1.000000      1.000000      1.000000       1.000000      1.000000
# 25%        8.000000      8.000000      8.000000       8.000000      8.000000
# 50%       11.000000     11.000000     11.000000      11.000000     11.000000
# 75%       14.000000     14.000000     14.000000      14.000000     14.000000
# max       90.000000     92.000000     91.000000      90.000000     94.000000
#
#        Release Clause  release_clause_dollars
# count    16643.000000            1.664300e+04
# mean    228201.273629            2.738415e+05
# std     299251.865865            3.591022e+05
# min       1000.000000            1.200000e+03
# 25%       2500.000000            3.000000e+03
# 50%      19800.000000            2.376000e+04
# 75%     431000.000000            5.172000e+05
# max     999000.000000            1.198800e+06
#
# [8 rows x 46 columns]

# %% [markdown]
# <b>3) What is the mean age and the median age for the players in this dataset?  How are the mean and median related to each other?</b>

# %% [markdown]
# Mean is 25.23, Median is 25, The mean is slightly larger than the median, this skews the data.

# %% [markdown]
# #### 4) Who is the oldest player in Argentina and how old is he?
# Hint: a groupby clause might help here

# %%
# code here
df.groupby("Nationality").max()
# Out:
#                       Unnamed: 0      ID                Name  Age  \
# Nationality
# Afghanistan                 7327  244175            N. Husin   26
# Albania                     9798  245792         Y. Ramadani   34
# Algeria                     9993  245565           Z. Ferhat   35
# Andorra                     5444  192937          Marc Vales   28
# Angola                      8493  242188                Rudy   34
# Antigua & Barbuda           8061  235773           R. Browne   27
# Argentina                   9964  246609           Y. Cabral   41
# Armenia                     9704  235989        Y. Movsisyan   32
# Australia                   9982  246196          Y. Mustafa   37
# Austria                     9994  245233        Z. Junuzović   37
# Azerbaijan                  9136  244279         R. Dadashov   32
# Barbados                    9219  200714           K. Pearce   31
# Belarus                     7731  244756          S. Chernik   31
# Belgium                     9999  246457        Álex Craninx   39
# Belize                      6640  232014          M. Salazar   25
# Benin                       8908  238475           S. Mounié   33
# Bermuda                     5412  202686            R. Lambe   28
# Bolivia                     9937  246407           R. Vargas   37
# Bosnia Herzegovina          9989  246257           Z. Kozulj   33
# Botswana                    8770  240614         R. Batlokwa   20
# Brazil                      9963  246447               Ícaro   40
# Bulgaria                    9604  245979         V. Bozhikov   35
# Burkina Faso                9831  243808           Z. Sanogo   32
# Burundi                     9711  242241         S. Berahino   28
# Cameroon                    9881  245867          Y. Songo'o   34
# Canada                      9997  245898  Z. Brault-Guillard   38
# Cape Verde                  9122  244193             Zé Luís   34
# Central African Rep.        7132  225934        G. Kondogbia   27
# Chad                        8545  244685    M. Mouandilmadji   25
# Chile                       9986  246150             Y. Urra   38
# ...                          ...     ...                 ...  ...
# Sierra Leone                8796  237051          U. Bangura   33
# Slovakia                    9679  244792          T. Hubočan   38
# Slovenia                    9988  246200      Z. Ljubijankič   35
# South Africa                9833  246307           X. Mlambo   34
# South Sudan                 6687  241502            K. Athiu   25
# Spain                       9943  246617       Óscar Whalley   39
# St Kitts Nevis              8678  243622          R. Sawyers   29
# St Lucia                    2825  209675         J. Donacien   24
# Sudan                       6503  245525          S. Mustafa   32
# Suriname                    8864  243732            M. Abena   29
# Sweden                      9996  246620        Z. Jovanovic   37
# Switzerland                 9862  246283            Y. Toure   36
# Syria                       9799  244967            Y. Kalfa   35
# São Tomé & Príncipe         3552  205425           Luís Leal   31
# Tanzania                    5340  245266         S. Chilunda   25
# Thailand                    8550  242351           W. Jakkit   30
# Chad                  https://cdn.sofifa.org/flags/106.png       73
# Chile                  https://cdn.sofifa.org/flags/55.png       85
# ...                                                    ...      ...
# Sierra Leone          https://cdn.sofifa.org/flags/138.png       74
# Slovakia               https://cdn.sofifa.org/flags/43.png       87
# Slovenia               https://cdn.sofifa.org/flags/44.png       90
# South Africa          https://cdn.sofifa.org/flags/140.png       76
# South Sudan           https://cdn.sofifa.org/flags/218.png       60
# Spain                  https://cdn.sofifa.org/flags/45.png       91
# St Kitts Nevis         https://cdn.sofifa.org/flags/89.png       71
# St Lucia               https://cdn.sofifa.org/flags/90.png       64
# Sudan                 https://cdn.sofifa.org/flags/141.png       65
# Suriname               https://cdn.sofifa.org/flags/92.png       70
# Sweden                 https://cdn.sofifa.org/flags/46.png       85
# Switzerland            https://cdn.sofifa.org/flags/47.png       83
# Syria                 https://cdn.sofifa.org/flags/186.png       78
# São Tomé & Príncipe   https://cdn.sofifa.org/flags/135.png       72
# Tanzania              https://cdn.sofifa.org/flags/143.png       76
# Thailand              https://cdn.sofifa.org/flags/188.png       68
# Togo                  https://cdn.sofifa.org/flags/144.png       79
# Trinidad & Tobago      https://cdn.sofifa.org/flags/93.png       74
# Tunisia               https://cdn.sofifa.org/flags/145.png       77
# Turkey                 https://cdn.sofifa.org/flags/48.png       81
# Uganda                https://cdn.sofifa.org/flags/146.png       70
# Ukraine                https://cdn.sofifa.org/flags/49.png       82
# United Arab Emirates  https://cdn.sofifa.org/flags/190.png       77
# United States          https://cdn.sofifa.org/flags/95.png       79
# Uruguay                https://cdn.sofifa.org/flags/60.png       91
# Uzbekistan            https://cdn.sofifa.org/flags/191.png       75
# Venezuela              https://cdn.sofifa.org/flags/61.png       81
# Wales                  https://cdn.sofifa.org/flags/50.png       88
# Zambia                https://cdn.sofifa.org/flags/147.png       73
# Zimbabwe              https://cdn.sofifa.org/flags/148.png       78
#
#                       Potential  \
# Nationality
# Afghanistan                  71
# Albania                      86
# Algeria                      85
# Andorra                      64
# Angola                       82
# Antigua & Barbuda            77
# Argentina                    94
# Armenia                      83
# Australia                    83
# Austria                      87
# Azerbaijan                   71
# Barbados                     66
# Belarus                      75
# Belgium                      92
# Belize                       61
# Benin                        82
# Bermuda                      70
# Bolivia                      78
# Bosnia Herzegovina           86
# Botswana                     68
# Brazil                       93
# Bulgaria                     77
# Burkina Faso                 84
# Burundi                      76
# Cameroon                     85
# Canada                       87
# Cape Verde                   87
# Central African Rep.         85
# Chad                         78
# Chile                        85
# ...                         ...
# Sierra Leone                 74
# Slovakia                     92
# Slovenia                     93
# South Africa                 84
# South Sudan                  63
# Spain                        93
# St Kitts Nevis               72
# St Lucia                     68
# Sudan                        72
# Suriname                     72
# Sweden                       85
# Switzerland                  87
# Syria                        80
# São Tomé & Príncipe          72
# Tanzania                     79
# Thailand                     70
# Togo                         81
# Trinidad & Tobago            74
# Tunisia                      81
# Turkey                       87
# Uganda                       74
# Ukraine                      88
# United Arab Emirates         78
# United States                87
# Uruguay                      91
# Uzbekistan                   75
# Switzerland               https://cdn.sofifa.org/teams/2/light/95.png     €9M
# Syria                    https://cdn.sofifa.org/teams/2/light/705.png     €9M
# São Tomé & Príncipe   https://cdn.sofifa.org/teams/2/light/110396.png   €2.8M
# Tanzania                 https://cdn.sofifa.org/teams/2/light/673.png   €525K
# Thailand              https://cdn.sofifa.org/teams/2/light/113157.png   €975K
# Togo                     https://cdn.sofifa.org/teams/2/light/680.png   €950K
# Trinidad & Tobago     https://cdn.sofifa.org/teams/2/light/112389.png   €700K
# Tunisia                   https://cdn.sofifa.org/teams/2/light/95.png     €9M
# Turkey                    https://cdn.sofifa.org/teams/2/light/97.png     €9M
# Uganda                   https://cdn.sofifa.org/teams/2/light/650.png   €725K
# Ukraine                  https://cdn.sofifa.org/teams/2/light/873.png     €9M
# United Arab Emirates     https://cdn.sofifa.org/teams/2/light/605.png  €10.5M
# United States             https://cdn.sofifa.org/teams/2/light/91.png   €975K
# Uruguay                  https://cdn.sofifa.org/teams/2/light/920.png   €975K
# Uzbekistan            https://cdn.sofifa.org/teams/2/light/112540.png     €6M
# Venezuela                https://cdn.sofifa.org/teams/2/light/917.png     €9M
# Wales                     https://cdn.sofifa.org/teams/2/light/97.png   €975K
# Zambia                   https://cdn.sofifa.org/teams/2/light/710.png   €925K
# Zimbabwe                 https://cdn.sofifa.org/teams/2/light/267.png   €975K
#
#                       ... Marking  StandingTackle  SlidingTackle  GKDiving  \
# Nationality           ...
# Afghanistan           ...    62.0            58.0           59.0      14.0
# Albania               ...    80.0            81.0           80.0      81.0
# Algeria               ...    79.0            81.0           84.0      73.0
# Andorra               ...    54.0            56.0           67.0       9.0
# Angola                ...    80.0            80.0           77.0      15.0
# Antigua & Barbuda     ...    68.0            69.0           68.0      11.0
# Argentina             ...    85.0            85.0           84.0      83.0
# Armenia               ...    54.0            57.0           63.0      15.0
# Australia             ...    82.0            77.0           76.0      81.0
# Austria               ...    80.0            82.0           80.0      78.0
# Azerbaijan            ...    61.0            63.0           62.0      14.0
# Barbados              ...    64.0            63.0           62.0      16.0
# Belarus               ...    42.0            54.0           47.0      68.0
# Belgium               ...    90.0            91.0           90.0      85.0
# Belize                ...    53.0            42.0           27.0       6.0
# Benin                 ...    76.0            76.0           73.0      71.0
# Bermuda               ...    39.0            50.0           40.0      10.0
# Bolivia               ...    79.0            71.0           70.0      67.0
# Bosnia Herzegovina    ...    75.0            81.0           80.0      80.0
# Botswana              ...    45.0            48.0           42.0      10.0
# Brazil                ...    90.0            90.0           87.0      85.0
# Bulgaria              ...    72.0            74.0           74.0      69.0
# Burkina Faso          ...    76.0            77.0           86.0      69.0
# Burundi               ...    59.0            61.0           58.0      10.0
# Cameroon              ...    80.0            84.0           78.0      83.0
# Canada                ...    70.0            70.0           68.0      75.0
# Cape Verde            ...    73.0            77.0           74.0      15.0
# Central African Rep.  ...    79.0            83.0           82.0      15.0
# Chad                  ...    21.0            25.0           23.0      13.0
# Chile                 ...    82.0            87.0           86.0      78.0
# ...                   ...     ...             ...            ...       ...
# Syria                       992000.0               1190400.0
# São Tomé & Príncipe           4200.0                  5040.0
# Tanzania                    945000.0               1134000.0
# Thailand                    300000.0                360000.0
# Togo                        831000.0                997200.0
# Trinidad & Tobago             9600.0                 11520.0
# Tunisia                     990000.0               1188000.0
# Turkey                      990000.0               1188000.0
# Uganda                      770000.0                924000.0
# Ukraine                     900000.0               1080000.0
# United Arab Emirates         18600.0                 22320.0
# United States               984000.0               1180800.0
# Uruguay                     943000.0               1131600.0
# Uzbekistan                  250000.0                300000.0
# Venezuela                   990000.0               1188000.0
# Wales                       998000.0               1197600.0
# Zambia                      610000.0                732000.0
# Zimbabwe                    958000.0               1149600.0
#
# [164 rows x 52 columns]

# %%
max_age = df.loc[df["Nationality"] == "Argentina",]["Age"].max()

# %%
df.loc[(df['Nationality'] == "Argentina") & (df["Age"] == max_age), :]
# Out:
#       Unnamed: 0      ID      Name  Age  \
# 7225        7225  142998  C. Muñoz   41
#
#                                                Photo Nationality  \
# 7225  https://cdn.sofifa.org/players/4/19/142998.png   Argentina
#
#                                      Flag  Overall  Potential  \
# 7225  https://cdn.sofifa.org/flags/52.png       68         68
#
#                               Club  ... Marking StandingTackle SlidingTackle  \
# 7225  CD Universidad de Concepción  ...    18.0           14.0          19.0
#
#       GKDiving GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 7225      67.0       65.0       68.0           71.0        68.0
#
#      Release Clause release_clause_dollars
# 7225        84000.0               100800.0
#
# [1 rows x 90 columns]

# %% [markdown]
# C. Munoz

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# <b> 1) What are the covariance and correlation between "GKDiving" and "GKHandling"? </b>
#
# a. What is the difference between covariance and correlation?
# b. What can you infer from the relationship between these variables?
# c. Would it be a good idea to include both of these in a regression model?

# %%
#code here
df[["GKDiving", "GKHandling" ]].cov()
# Out:
#               GKDiving  GKHandling
# GKDiving    313.125370  290.282081
# GKHandling  290.282081  285.843284

# %%
df[["GKDiving", "GKHandling" ]].corr()
# Out:
#             GKDiving  GKHandling
# GKDiving     1.00000     0.97028
# GKHandling   0.97028     1.00000

# %% [markdown]
# 1. Correlation is a standardized version of covariance.
# 2. They are very strongly positively correlated.
# 3. No, because they are so strongly correlated they are probably multicollinear.

# %% [markdown]
# <b>2) Fit a linear regression using the `ols` module of statsmodels</b>
#
# Let's see how well each players' in-game stats reflect their real-world monetary value as a player. We  will not be considering real-world factors for this model, just the variables listed below.
#
# - y variable: Release Clause (the one in euros)
# - x variables: 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression','Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure','Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling','GKKicking', 'GKPositioning', 'GKReflexes'
#
# Once you have fit the linear regression, display the results (coefficient values, $R^2$, etc.). Displaying the results can be done with one method!

# %%
#code here
import statsmodels.api as sm
from statsmodels.formula.api import ols

Y = df['Release Clause']
X = df[['Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression','Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure','Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling','GKKicking', 'GKPositioning', 'GKReflexes']]

x = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
results.summary()
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-44-8e1567448016> in <module>
#       7
#       8 x = sm.add_constant(X)
# ----> 9 model = sm.OLS(Y,X)
#      10 results = model.fit()
#      11 results.summary()
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     661             weights = weights.squeeze()
#     662         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 663                                   weights=weights, hasconst=hasconst, **kwargs)
#     664         nobs = self.exog.shape[0]
#     665         weights = self.weights
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     177     """
#     178     def __init__(self, endog, exog, **kwargs):
# --> 179         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     180         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     181
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      62         hasconst = kwargs.pop('hasconst', None)
#      63         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 64                                       **kwargs)
#      65         self.k_constant = self.data.k_constant
#      66         self.exog = self.data.exog
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      85
#      86     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 87         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      88         # kwargs arrays could have changed, easier to just attach here
#      89         for key in kwargs:
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     631     klass = handle_data_class_factory(endog, exog)
#     632     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 633                  **kwargs)
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
# ---> 79         self._handle_constant(hasconst)
#      80         self._check_integrity()
#      81         self._cache = resettable_cache()
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     131             ptp_ = self.exog.ptp(axis=0)
#     132             if not np.isfinite(ptp_).all():
# --> 133                 raise MissingDataError('exog contains inf or nans')
#     134             const_idx = np.where(ptp_ == 0)[0].squeeze()
#     135             self.k_constant = const_idx.size
#
# MissingDataError: exog contains inf or nans

# %% [markdown]
# <b> 3) Interpret the results of the regression.
#
# Two players have the following stats:
#
# 1) Finishing : 1, Heading Accuracy : 10, ShortPassing : 5
#
# 2) Finishing : 1, Heading Accuracy :  8, ShortPassing : 5
#
# Assume all the remaining stats are the same for both players. By how much can we expect the Release Clause of each player to be different? Explain how you obtained your calculation. </b>

# %%
results.params['HeadingAccuracy'] = 2

# %% [markdown]
# // answer here //
